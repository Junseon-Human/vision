# %%
# deep-face 사용

# %%
# %pip install scipy
# Out:
# ...
#   Using cached scipy-1.10.1-cp38-cp38-win_amd64.whl.metadata (58 kB)
# ...
# Using cached scipy-1.10.1-cp38-cp38-win_amd64.whl (42.2 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %conda install -c conda-forge dlib
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: c:\Users\main\miniconda3\envs\deepface
#
#   added / updated specs:
#     - dlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cuda-version-11.8          |       h70ddcb2_3          21 KB  conda-forge
#     cudatoolkit-11.8.0         |      h09e9e62_13       692.5 MB  conda-forge
#     cudnn-8.9.7.29             |       he6de189_3       436.9 MB  conda-forge
#     dlib-19.24.6               |cuda118py38had58105_0         3.9 MB  conda-forge
#     libjpeg-turbo-3.1.0        |       h2466b09_0         819 KB  conda-forge
#     libpng-1.6.47              |       h7a4582a_0         338 KB  conda-forge
#     libzlib-wapi-1.2.13        |       h2466b09_6          55 KB  conda-forge
# ...
