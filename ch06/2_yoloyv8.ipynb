# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

model = YOLO("yolov8n.pt")
image_path = "bts.jpg"

results = model.predict(image_path)
print(results)

res_img = results[0].plot()

plt.figure(figsize=(10, 8))
plt.imshow(cv2.cvtColor(res_img, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.title("yolov8n")
plt.show()
# Out:
# image 1/1 c:\Users\main\Desktop\vision_project\ch06\bts.jpg: 448x640 9 persons, 7 ties, 20.9ms
# Speed: 2.9ms preprocess, 20.9ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 99, 161,  13],
#         [100, 162,  14],
#         [102, 164,  18],
#         ...,
#         [102, 169,   0],
#         [101, 168,   0],
#         [101, 168,   0]],
#
#        [[101, 163,  15],
#         [105, 167,  19],
#         [103, 165,  17],
#         ...,
#         [102, 169,   0],
#         [101, 168,   0],
#         [102, 169,   0]],
#
#        [[102, 166,  17],
#         [101, 165,  16],
#         [ 97, 161,  12],
#         ...,
#         [101, 168,   0],
#         [102, 169,   0],
#         [102, 169,   0]],
#
#        ...,
#
#        [[192, 199, 178],
#         [192, 199, 178],
#         [193, 200, 179],
#         ...,
#         [184, 195, 175],
#         [182, 193, 173],
#         [179, 190, 170]],
#
#        [[198, 205, 184],
#         [197, 204, 183],
#         [197, 204, 183],
#         ...,
#         [187, 198, 178],
#         [187, 198, 178],
#         [188, 199, 179]],
#
#        [[197, 204, 183],
#         [198, 205, 184],
#         [195, 202, 181],
#         ...,
#         [189, 200, 180],
#         [189, 200, 180],
#         [188, 199, 179]]], shape=(533, 800, 3), dtype=uint8)
# orig_shape: (533, 800)
# path: 'c:\\Users\\main\\Desktop\\vision_project\\ch06\\bts.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 2.930700000433717, 'inference': 20.905100000163657, 'postprocess': 2.2219000002223765}]

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

model = YOLO("yolov5n.pt")
image_path = "bts.jpg"

results = model.predict(image_path)
print(results)

res_img = results[0].plot()

plt.figure(figsize=(10, 8))
plt.imshow(cv2.cvtColor(res_img, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.title("yolov5n")
plt.show()
# Out:
# PRO TIP  Replace 'model=yolov5n.pt' with new 'model=yolov5nu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
#
# image 1/1 c:\Users\main\Desktop\vision_project\ch06\bts.jpg: 448x640 7 persons, 4 ties, 1 remote, 20.6ms
# Speed: 3.1ms preprocess, 20.6ms inference, 5.0ms postprocess per image at shape (1, 3, 448, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 99, 161,  13],
#         [100, 162,  14],
#         [102, 164,  18],
#         ...,
#         [102, 169,   0],
#         [101, 168,   0],
#         [101, 168,   0]],
#
#        [[101, 163,  15],
#         [105, 167,  19],
#         [103, 165,  17],
#         ...,
#         [102, 169,   0],
#         [101, 168,   0],
#         [102, 169,   0]],
#
#        [[102, 166,  17],
#         [101, 165,  16],
#         [ 97, 161,  12],
#         ...,
#         [101, 168,   0],
#         [102, 169,   0],
#         [102, 169,   0]],
#
#        ...,
#
#        [[192, 199, 178],
#         [192, 199, 178],
#         [193, 200, 179],
#         ...,
#         [184, 195, 175],
#         [182, 193, 173],
#         [179, 190, 170]],
#
#        [[198, 205, 184],
#         [197, 204, 183],
#         [197, 204, 183],
#         ...,
#         [187, 198, 178],
#         [187, 198, 178],
#         [188, 199, 179]],
#
#        [[197, 204, 183],
#         [198, 205, 184],
#         [195, 202, 181],
#         ...,
#         [189, 200, 180],
#         [189, 200, 180],
#         [188, 199, 179]]], shape=(533, 800, 3), dtype=uint8)
# orig_shape: (533, 800)
# path: 'c:\\Users\\main\\Desktop\\vision_project\\ch06\\bts.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 3.1106000005820533, 'inference': 20.613400000002002, 'postprocess': 4.963299999872106}]

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

model = YOLO("yolo11n.pt")
image_path = "bts.jpg"

results = model.predict(image_path)
print(results)

res_img = results[0].plot()

plt.figure(figsize=(10, 8))
plt.imshow(cv2.cvtColor(res_img, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.title("yolo11n")
plt.show()
# Out:
# image 1/1 c:\Users\main\Desktop\vision_project\ch06\bts.jpg: 448x640 11 persons, 4 ties, 21.8ms
# Speed: 2.5ms preprocess, 21.8ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 99, 161,  13],
#         [100, 162,  14],
#         [102, 164,  18],
#         ...,
#         [102, 169,   0],
#         [101, 168,   0],
#         [101, 168,   0]],
#
#        [[101, 163,  15],
#         [105, 167,  19],
#         [103, 165,  17],
#         ...,
#         [102, 169,   0],
#         [101, 168,   0],
#         [102, 169,   0]],
#
#        [[102, 166,  17],
#         [101, 165,  16],
#         [ 97, 161,  12],
#         ...,
#         [101, 168,   0],
#         [102, 169,   0],
#         [102, 169,   0]],
#
#        ...,
#
#        [[192, 199, 178],
#         [192, 199, 178],
#         [193, 200, 179],
#         ...,
#         [184, 195, 175],
#         [182, 193, 173],
#         [179, 190, 170]],
#
#        [[198, 205, 184],
#         [197, 204, 183],
#         [197, 204, 183],
#         ...,
#         [187, 198, 178],
#         [187, 198, 178],
#         [188, 199, 179]],
#
#        [[197, 204, 183],
#         [198, 205, 184],
#         [195, 202, 181],
#         ...,
#         [189, 200, 180],
#         [189, 200, 180],
#         [188, 199, 179]]], shape=(533, 800, 3), dtype=uint8)
# orig_shape: (533, 800)
# path: 'c:\\Users\\main\\Desktop\\vision_project\\ch06\\bts.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 2.5384999989910284, 'inference': 21.84099999976752, 'postprocess': 2.3469999996450497}]
